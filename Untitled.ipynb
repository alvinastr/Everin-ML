# %% [markdown]
# # Import Dependencies

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import imghdr

from matplotlib import pyplot as plt
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # Load Data

# %%
data_train_path = 'data/image/split/train'
data_test_path = 'data/image/split/test'
data_val_path = 'data/image/split/val'

# %%
img_width = 256
img_height = 256
num_channels = 3

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3731 files belonging to 51 classes.

# %%
data_cat = data_train.class_names
data_cat
# Out:
# ['ABC Kopi Susu',
#  'Acaraki',
#  'Apel',
#  'Bakso',
#  'Beef Teriyaki',
#  'Beng Beng',
#  'Chocopie',
#  'Coca Cola',
#  'Durian',
#  'Egg Roll',
#  'Fanta',
#  'Fitbar',
#  'Floridina',
#  'Golda Dolce',
#  'Ice Cream',
#  'Indomie Goreng',
#  'Iso Plus',
#  'Japota',
#  'Jeruk',
#  'Kitkat',
#  'Mie Ayam',
#  'Milo',
#  'Nasi Padang',
#  'Nasi Uduk',
#  'Nescafe Ice Black',
#  'Nipis Madu',
#  'Nu Green Tea',
#  'Oat Milk',
#  'Onigiri',
#  'Oreo',
#  'Pacar Cina',
#  'Pisang',
#  'Pocari Sweat',
#  'Pocky Chocolate',
#  'Rendang',
#  'Root Beer Kaleng',
#  'Roti Tawar',
#  'Sarigandum',
#  'Semangka',
#  'Sprite',
#  'Sushi',
#  'Tahu Goreng',
#  'Tango',
#  'Taro',
#  'Teh Botol',
#  'Teh Kotak',
#  'Ultra Milk',
#  'You c orange',
#  'Yougurt',
#  'nasi goreng',
#  'olatte']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 1051 files belonging to 51 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 587 files belonging to 51 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
data_train
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = models.Sequential([
    layers.Input(shape=(img_height, img_width, num_channels)),  # Menggunakan Input layer
    layers.Rescaling(1./255),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    
    layers.Flatten(),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(len(train_generator.class_indices), activation='softmax')  # Ganti dengan jumlah kelas Anda
])

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 254, 254, 16)      448
#
#  max_pooling2d_3 (MaxPoolin  (None, 127, 127, 16)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_4 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_5 (MaxPoolin  (None, 30, 30, 16)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 14400)             0
#
#  dense_2 (Dense)             (None, 256)               3686656
#
#  dense_3 (Dense)             (None, 1)                 257
#
# ...
# Total params: 3696625 (14.10 MB)
# Trainable params: 3696625 (14.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25,
    callbacks=[early_stopping]
)

# %%
# Out:
# Epoch 1/20
# 117/117 [==============================] - 55s 456ms/step - loss: -369976770560.0000 - accuracy: 0.0137 - val_loss: -2961663590400.0000 - val_accuracy: 0.0133
# Epoch 2/20
# 117/117 [==============================] - 53s 449ms/step - loss: -67912614281216.0000 - accuracy: 0.0137 - val_loss: -253115492204544.0000 - val_accuracy: 0.0133
# Epoch 3/20
# 117/117 [==============================] - 54s 454ms/step - loss: -1168203455660032.0000 - accuracy: 0.0137 - val_loss: -2889998131003392.0000 - val_accuracy: 0.0133
# Epoch 4/20
# 117/117 [==============================] - 53s 452ms/step - loss: -7559175726956544.0000 - accuracy: 0.0137 - val_loss: -14734016305430528.0000 - val_accuracy: 0.0133
# Epoch 5/20
# 117/117 [==============================] - 53s 450ms/step - loss: -29405117782425600.0000 - accuracy: 0.0137 - val_loss: -49459542005645312.0000 - val_accuracy: 0.0133
# Epoch 6/20
# ...

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'data/image/split/test/ABC Kopi Susu/1701477428_1696223749_1696035956_ABC252520Minuman252520Kopi252520Chocomalt252520Coffee-430x430.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is Teh Kotak with accuracy of 40.87
